# %% [markdown]
# <a href="https://colab.research.google.com/github/gmm39/CS4410_GMcKenzie/blob/main/Homework1_GMcKenzie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gage McKenzie\
# CS4410\
# Homework 1

# %%
import pandas as pd

# 9.16 (a-b)
diamond = pd.read_csv('https://raw.githubusercontent.com/Pratik-Bhujade/Diamond-Dataset/82246f3bdd62f1ef5e27d3b415c371f0ed40ffd9/DiamondData.csv')

# %%
# 9.16 (c)
diamond.head(7)
# Out:
#    carat        cut color clarity  depth  table    price     x     y     z
# 0   1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1   0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2   1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3   0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4   2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5   0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 6   0.46      Ideal     G    VVS1   60.7   57.0   1453.0  4.98  5.03  3.04

# %%
# 9.16 (d)
diamond.tail(7)
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 49993   1.00       Good     F      IF   60.7   64.0   9660.0  6.42  6.40  3.89
# 49994   0.50  Very Geod     I     SI1   62.4   58.0   1048.0  5.00  5.06  3.14
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52

# %%
# 9.16 (e)
diamond.describe()
# Out:
#               carat         depth         table         price             x  \
# count  50000.000000  49529.000000  49610.000000  49747.000000  49779.000000
# mean       0.906952     61.748402     57.464787   3938.803486      5.731776
# std        2.069722      1.429476      2.242345   3994.643235      1.122125
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.050000     62.500000     59.000000   5339.000000      6.540000
# max       49.990359     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  49667.000000  49572.000000
# mean       5.733675      3.539514
# std        1.119993      0.706533
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
# 9.16 (f)
diamond.cut.describe()
# Out:
# count     50000
# unique        6
# top       Ideal
# freq      19918
# Name: cut, dtype: object

# %%
diamond.color.describe()
# Out:
# count     50000
# unique        7
# top           G
# freq      10493
# Name: color, dtype: object

# %%
diamond.clarity.describe()
# Out:
# count     50000
# unique        8
# top         SI1
# freq      12120
# Name: clarity, dtype: object

# %%
# 9.16 (g)
diamond.cut.unique()
# Out:
# array(['Fair', 'Ideal', 'Premium', 'Very Good', 'Very Geod', 'Good'],
#       dtype=object)

# %%
diamond.color.unique()
# Out:
# array(['G', 'E', 'J', 'F', 'H', 'D', 'I'], dtype=object)

# %%
diamond.clarity.unique()
# Out:
# array(['SI1', 'VS2', 'VS1', 'SI2', 'VVS1', 'VVS2', 'I1', 'IF'],
#       dtype=object)

# %%
# 9.16 (h)
# %matplotlib inline
histogram = diamond.hist(figsize=(15, 10))
